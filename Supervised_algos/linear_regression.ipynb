# %% [markdown]
# ## Liner Regression
# This is a simple example of linear regression being used.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
df = pd.read_csv('headbrain.csv')
print(df.shape)
df.head()
# Out:
# (237, 4)
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %% [markdown]
# #### Let's find the linear relationship between head size and brain weight.

# %%
X = df['Head Size(cm^3)'].values
Y = df['Brain Weight(grams)'].values

# %% [markdown]
# ##### we will use the formula to calculate b1, b0

# %%
mean_x = np.mean(X)
mean_y = np.mean(Y)

m = len(x)
# the formula for b0, b1
num = 0
denom = 0
for i in range(m):
    num += (X[i] - mean_x) * (Y[i] - mean_y)
    denom  += (X[i] - mean_x) **2

b1 = num/denom
b0  = mean_y - (b1 * mean_x)

#lets see the coefficients
print(b1, b0)
# Out:
# 0.26342933948939945 325.57342104944223

# %% [markdown]
# for the equation mx+c here b1 is the m value , b0 is the c value and x is the data that is haed size.
# Now let's plot what we got.

# %%
max_x = np.max(X) + 100
min_x = np.min(X) - 100

#Line values
x = np.linspace(min_x, max_x, 1000)
y = b0 + b1 * x #(c + m * x)

#Plot
plt.plot(x, y, color = '#58b970', label = 'Regression line')

#plotting the points
plt.scatter(X, Y, c = '#ef5423', label = 'Scatter plot')

plt.xlabel('Head size')
plt.ylabel('Brain weight')
plt.legend()
plt.show()

# %% [markdown]
# ##### R-squared method to determine how good this method is

# %%
st = 0
sr = 0
for i in range(m):
    y_pred = b0 + b1 * X[i]
    st += (Y[i] - mean_y) ** 2
    sr += (Y[i] - y_pred) ** 2

r2 = 1 - (sr/st)
print(r2)
# Out:
# 0.6393117199570003

# %% [markdown]
# ### Till here it's all simple and cool, but now I'm going to implement the same using a library called scikit-learn (sklearn).
